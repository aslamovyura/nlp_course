# %% [markdown]
# # Dataset Preparation

# %%
import json
import csv
from types import SimpleNamespace
import os

# %% [markdown]
# Load original dataset from LUIS (or Language Studio)

# %%
datapath = f'data.json'

with open(datapath, 'r') as f:
    data = json.load(f)

# print(data)

# %% [markdown]
# Load Intent labels dictionary

# %%
intent_labels = {}

print('Loading intent labels...')
if 'intents' in data['assets']:
    intent_labels = {intent_['category']: i for i, intent_ in enumerate(data['assets']['intents'])}
    
    print(json.dumps(intent_labels, indent=4))
else:
    print('no intent labels found!')
# Out:
# Loading intent labels...
# {
#     "Accept": 0,
#     "AskForEquipmentInstallation": 1,
#     "AskForInterest": 2,
#     "AskForPrice": 3,
#     "AskIfBuy": 4,
#     "AskIfHaveEquipment": 5,
#     "AskIfSell": 6,
#     "Decline": 7,
#     "DeclinePrice": 8,
#     "DeclineToBuy": 9,
#     "DeclineToSell": 10,
#     "DoNotHaveEquipment": 11,
#     "HaveDeinstalledEquipment": 12,
#     "HaveEquipment": 13,
#     "HaveInstalledEquipment": 14,
#     "None": 15,
#     "OfferPrice": 16,
#     "WantDeal": 17,
#     "WantToBuy": 18,
#     "WantToSell": 19
# }

# %% [markdown]
# Load Entity labels dictionary

# %%
entity_labels = {}

print('Loading entity labels...')
if 'entities' in data['assets']:
    entity_labels = {entity_['category']: i for i, entity_ in enumerate(data['assets']['entities'])}
    
    print(json.dumps(entity_labels, indent=4))
else:
    print('no intent labels found!')
# Out:
# Loading entity labels...
# {
#     "Action.AlreadyBought": 0,
#     "Action.AlreadySold": 1,
#     "Action.Potential": 2,
#     "Action.ToSell": 3,
#     "Action.ToBuy": 4,
#     "Action.Decline": 5,
#     "Action.Accept": 6,
#     "Action.Have": 7,
#     "Action.Interested": 8,
#     "Action.OfferOrPay": 9,
#     "Actor.FirstPerson": 10,
#     "Actor.SecondPerson": 11,
#     "Actor.ThirdPerson": 12,
#     "AssetAttribute": 13,
#     "Attachment": 14,
#     "Condition.AsIs": 15,
#     "Condition.Excellent": 16,
#     "Condition.Good": 17,
#     "Condition.MissingParts": 18,
#     "Condition.New": 19,
#     "Condition.Refurbished": 20,
#     "Condition.VeryGood": 21,
#     "Condition.Working": 22,
#     "Condition.Poor": 23,
#     "Quantity.Any": 24,
#     "Quantity.Lot": 25,
#     "Quantity.Number": 26,
#     "Equipment.Vintage": 27,
#     "Equipment.MakeModel": 28,
#     "Equipment.Type": 29,
#     "Composition.Complete": 30,
#     "Composition.SpareParts": 31,
#     "State.Installed": 32,
#     "State.Deinstalled": 33,
#     "State.Demonstrable": 34,
#     "State.NonDemonstrable": 35,
#     "State.Idled": 36,
#     "State.Crated": 37,
#     "Equipment.Location": 38,
#     "Equipment.WaferSize": 39,
#     "Facility.Storage": 40,
#     "Facility.Production": 41,
#     "Price.Value": 42,
#     "Category.ExWork": 43,
#     "Category.Other": 44,
#     "Category.SellerAsk": 45,
#     "Category.BuyerBid": 46,
#     "Category.MinPrice": 47,
#     "Category.MaxPrice": 48,
#     "Category.Range": 49,
#     "Price.Currency": 50,
#     "Price.LotSize": 51,
#     "QuestionAttribute": 52,
#     "Request": 53,
#     "Timeline": 54
# }

# %%
utterances = data['assets']['utterances']
print(f'Utterances: {len(utterances)}')
# Out:
# Utterances: 6862

# %% [markdown]
# ## Create Intents dataset

# %%
intent_dataset_name = 'intents-gen.csv'

if os.path.exists(intent_dataset_name):
    os.remove(intent_dataset_name)

with open(intent_dataset_name, 'w', newline='') as f:
    writer = csv.writer(f)

    header = ['intent', 'utterance']
    writer.writerow(header)

    for utt in utterances:
        row = [utt['intent'], utt['text']]
        writer.writerow(row)

# %% [markdown]
# ## Create Entities dataset

# %%
label_2_tag = {
    "Action.AlreadyBought": "act_bought",
    "Action.AlreadySold": "act_sold",
    "Action.Potential": "act_pot",
    "Action.ToSell": "act_sell",
    "Action.ToBuy": "act_buy",
    "Action.Decline": "act_dec",
    "Action.Accept": "act_acc",
    "Action.Have": "act_have",
    "Action.Interested": "act_int",
    "Action.OfferOrPay": "act_pay",
    "Actor.FirstPerson": "per_fir",
    "Actor.SecondPerson": "per_sec",
    "Actor.ThirdPerson": "per_thr",
    "AssetAttribute": "aattr",
    "Attachment": "attach",
    "Condition.AsIs": "cond_asis",
    "Condition.Excellent": "cond_exc",
    "Condition.Good": "cond_good",
    "Condition.MissingParts": "cond_miss",
    "Condition.New": "cond_new",
    "Condition.Refurbished": "cond_ref",
    "Condition.VeryGood": "cond_vgood",
    "Condition.Working": "cond_work",
    "Condition.Poor": "cond_poor",
    "Quantity.Any": "qty_any",
    "Quantity.Lot": "qty_lot",
    "Quantity.Number": "qty_num",
    "Equipment.Vintage": "eq_vint",
    "Equipment.MakeModel": "eq_mm",
    "Equipment.Type": "eq_type",
    "Composition.Complete": "comp_compl",
    "Composition.SpareParts": "comp_sp",
    "State.Installed": "state_inst",
    "State.Deinstalled": "state_dinst",
    "State.Demonstrable": "state_demo",
    "State.NonDemonstrable": "state_ndemo",
    "State.Idled": "state_idle",
    "State.Crated": "state_crat",
    "Equipment.Location": "eq_loc",
    "Equipment.WaferSize": "eq_wafs",
    "Facility.Storage": "fac_stor",
    "Facility.Production": "fac_prod",
    "Price.Value": "pr_val",
    "Category.ExWork": "cat_exw",
    "Category.Other": "cat_oth",
    "Category.SellerAsk": "cat_ask",
    "Category.BuyerBid": "cat_bid",
    "Category.MinPrice": "cat_min",
    "Category.MaxPrice": "cat_max",
    "Category.Range": "cat_rang",
    "Price.Currency": "pr_curr",
    "Price.LotSize": "pr_size",
    "QuestionAttribute": "qattr",
    "Request": "req",
    "Timeline": "tline"
}

label_2_btag = {
    "Action.AlreadyBought": "B-act_bought",
    "Action.AlreadySold": "B-act_sold",
    "Action.Potential": "B-act_pot",
    "Action.ToSell": "B-act_sell",
    "Action.ToBuy": "B-act_buy",
    "Action.Decline": "B-act_dec",
    "Action.Accept": "B-act_acc",
    "Action.Have": "B-act_have",
    "Action.Interested": "B-act_int",
    "Action.OfferOrPay": "B-act_pay",
    "Actor.FirstPerson": "B-per_fir",
    "Actor.SecondPerson": "B-per_sec",
    "Actor.ThirdPerson": "B-per_thr",
    "AssetAttribute": "B-aattr",
    "Attachment": "B-attach",
    "Condition.AsIs": "B-cond_asis",
    "Condition.Excellent": "B-cond_exc",
    "Condition.Good": "B-cond_good",
    "Condition.MissingParts": "B-cond_miss",
    "Condition.New": "B-cond_new",
    "Condition.Refurbished": "B-cond_ref",
    "Condition.VeryGood": "B-cond_vgood",
    "Condition.Working": "B-cond_work",
    "Condition.Poor": "B-cond_poor",
    "Quantity.Any": "B-qty_any",
    "Quantity.Lot": "B-qty_lot",
    "Quantity.Number": "B-qty_num",
    "Equipment.Vintage": "B-eq_vint",
    "Equipment.MakeModel": "B-eq_mm",
    "Equipment.Type": "B-eq_type",
    "Composition.Complete": "B-comp_compl",
    "Composition.SpareParts": "B-comp_sp",
    "State.Installed": "B-state_inst",
    "State.Deinstalled": "B-state_dinst",
    "State.Demonstrable": "B-state_demo",
    "State.NonDemonstrable": "B-state_ndemo",
    "State.Idled": "B-state_idle",
    "State.Crated": "B-state_crat",
    "Equipment.Location": "B-eq_loc",
    "Equipment.WaferSize": "B-eq_wafs",
    "Facility.Storage": "B-fac_stor",
    "Facility.Production": "B-fac_prod",
    "Price.Value": "B-pr_val",
    "Category.ExWork": "B-cat_exw",
    "Category.Other": "B-cat_oth",
    "Category.SellerAsk": "B-cat_ask",
    "Category.BuyerBid": "B-cat_bid",
    "Category.MinPrice": "B-cat_min",
    "Category.MaxPrice": "B-cat_max",
    "Category.Range": "B-cat_rang",
    "Price.Currency": "B-pr_curr",
    "Price.LotSize": "B-pr_size",
    "QuestionAttribute": "B-qattr",
    "Request": "B-req",
    "Timeline": "B-tline"
}

label_2_itag = {
    "Action.AlreadyBought": "I-act_bought",
    "Action.AlreadySold": "I-act_sold",
    "Action.Potential": "I-act_pot",
    "Action.ToSell": "I-act_sell",
    "Action.ToBuy": "I-act_buy",
    "Action.Decline": "I-act_dec",
    "Action.Accept": "I-act_acc",
    "Action.Have": "I-act_have",
    "Action.Interested": "I-act_int",
    "Action.OfferOrPay": "I-act_pay",
    "Actor.FirstPerson": "I-per_fir",
    "Actor.SecondPerson": "I-per_sec",
    "Actor.ThirdPerson": "I-per_thr",
    "AssetAttribute": "I-aattr",
    "Attachment": "I-attach",
    "Condition.AsIs": "I-cond_asis",
    "Condition.Excellent": "I-cond_exc",
    "Condition.Good": "I-cond_good",
    "Condition.MissingParts": "I-cond_miss",
    "Condition.New": "I-cond_new",
    "Condition.Refurbished": "I-cond_ref",
    "Condition.VeryGood": "I-cond_vgood",
    "Condition.Working": "I-cond_work",
    "Condition.Poor": "I-cond_poor",
    "Quantity.Any": "I-qty_any",
    "Quantity.Lot": "I-qty_lot",
    "Quantity.Number": "I-qty_num",
    "Equipment.Vintage": "I-eq_vint",
    "Equipment.MakeModel": "I-eq_mm",
    "Equipment.Type": "I-eq_type",
    "Composition.Complete": "I-comp_compl",
    "Composition.SpareParts": "I-comp_sp",
    "State.Installed": "I-state_inst",
    "State.Deinstalled": "I-state_dinst",
    "State.Demonstrable": "I-state_demo",
    "State.NonDemonstrable": "I-state_ndemo",
    "State.Idled": "I-state_idle",
    "State.Crated": "I-state_crat",
    "Equipment.Location": "I-eq_loc",
    "Equipment.WaferSize": "I-eq_wafs",
    "Facility.Storage": "I-fac_stor",
    "Facility.Production": "I-fac_prod",
    "Price.Value": "I-pr_val",
    "Category.ExWork": "I-cat_exw",
    "Category.Other": "I-cat_oth",
    "Category.SellerAsk": "I-cat_ask",
    "Category.BuyerBid": "I-cat_bid",
    "Category.MinPrice": "I-cat_min",
    "Category.MaxPrice": "I-cat_max",
    "Category.Range": "I-cat_rang",
    "Price.Currency": "I-pr_curr",
    "Price.LotSize": "I-pr_size",
    "QuestionAttribute": "I-qattr",
    "Request": "I-req",
    "Timeline": "I-tline"
}

# %%
ent_data = []

# for utt_ in utterances[:10]:
for utt_ in utterances:
    text_ = utt_['text']
    
    entities_ = []
    for ent_ in utt_['entities']:
        start = int(ent_['offset'])
        end = start + int(ent_['length'])
        tag = label_2_tag[ent_['category']]

        entities_.append((start,end,tag))

    # if len(entities_) == 0:
    #     print(f"Skip utterance: `{text_}`")
    #     continue

    ent_data.append((text_, {'entities': entities_}))
    
    
# print(ent_data)

# %%
# !python3 -m spacy download en_core_web_sm
# !python3 -m spacy download en_core_web_lg

import spacy
from spacy.training import offsets_to_biluo_tags, biluo_to_iob

# nlp = spacy.load('en_core_web_sm')
nlp = spacy.load('en_core_web_lg')
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 6.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from en-core-web-lg==3.5.0) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.28.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.65.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: jinja2 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.6)
# Requirement already satisfied: setuptools in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (65.6.3)
# Requirement already satisfied: numpy>=1.15.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.23.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
entities_dataset_name = 'entities-gen.csv'

if os.path.exists(entities_dataset_name):
    os.remove(entities_dataset_name)

with open(entities_dataset_name, 'w', newline='') as f:
    writer = csv.writer(f)

    header = ['utterance', 'labels']
    writer.writerow(header)

    for text, annot in ent_data:
        doc = nlp(text)

        utterance_ = ' '.join([str(t) for t in doc])
        tags_ = offsets_to_biluo_tags(doc, annot['entities'])
        # print(utterance_)
        # print(tags_)
        # tags_ = [str(t_).replace("U-", "B-").replace("L-", "I-") for t_ in tags_]
        # tags_ = offsets_to_biluo_tags(nlp.make_doc(text), annot['entities'])
        tags_ = biluo_to_iob(tags_)

        labels = ' '.join(tags_)

        row = [utterance_, labels]
        writer.writerow(row)
# Out:
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "$1mil-$1.6mil for a tool." with entities "[(0, 1, 'pr_curr'), (1, 5, 'pr_val'), (6, 7, 'pr_c...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "$325k+ range." with entities "[(0, 1, 'pr_curr'), (1, 5, 'pr_val'), (7, 12, 'cat...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "€700.000~755.000 for each." with entities "[(0, 1, 'pr_curr'), (1, 8, 'pr_val'), (9, 16, 'pr_...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "1-$1.5k each for the accupols." with entities "[(0, 1, 'pr_val'), (2, 3, 'pr_curr'), (3, 7, 'pr_v...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "7 900 fr /ea." with entities "[(0, 5, 'pr_val'), (6, 8, 'pr_curr'), (10, 12, 'pr...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "7k*2." with entities "[(0, 2, 'pr_val'), (2, 4, 'pr_size')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "8k$ as is." with entities "[(0, 2, 'pr_val'), (2, 3, 'pr_curr'), (4, 9, 'cond...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ad830 is us$38,000/set." with entities "[(0, 5, 'eq_mm'), (9, 11, 'pr_curr'), (11, 12, 'pr...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "allowable budget cap at 58k€." with entities "[(10, 16, 'cat_bid'), (17, 20, 'cat_max'), (24, 27...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "around eur€67k." with entities "[(7, 11, 'pr_curr'), (11, 14, 'pr_val')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "at around $5,200-$15,200 range." with entities "[(10, 11, 'pr_curr'), (11, 16, 'pr_val'), (17, 18,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "budget is usd$ 30,100." with entities "[(0, 6, 'cat_bid'), (10, 13, 'pr_curr'), (13, 14, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "can offer $22500-$33500." with entities "[(0, 3, 'act_pot'), (4, 9, 'act_pay'), (10, 11, 'p...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "expected to sell for 93,700$." with entities "[(0, 8, 'act_pot'), (9, 16, 'act_sell'), (21, 27, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "expecting to sell this unit at 48k£." with entities "[(10, 17, 'act_sell'), (23, 27, 'eq_type'), (31, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "for only 5100€." with entities "[(9, 13, 'pr_val'), (13, 14, 'pr_curr')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "have an installed ltx-credence diamond x." with entities "[(0, 4, 'act_have'), (8, 17, 'state_inst'), (18, 4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "he is asking for ￥24k obo for these." with entities "[(0, 2, 'per_thr'), (6, 12, 'cat_ask'), (17, 18, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "highly discounted rate of 225k$ exw." with entities "[(26, 30, 'pr_val'), (30, 31, 'pr_curr'), (32, 35,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "his last asking price was 600,000￥." with entities "[(9, 21, 'cat_ask'), (26, 33, 'pr_val'), (33, 34, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "https//caeonline.com/buy/probers/accretech-tsk-uf-..." with entities "[(25, 32, 'eq_type'), (33, 53, 'eq_mm')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "i am here to on behalf of my colleague charlie to ..." with entities "[(0, 1, 'per_fir'), (60, 72, 'act_buy'), (76, 117,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "i am interested to purchase 8"-12" the following m..." with entities "[(0, 1, 'per_fir'), (2, 15, 'act_int'), (16, 27, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "i can offer about 1-2m." with entities "[(0, 1, 'per_fir'), (2, 5, 'act_pot'), (6, 11, 'ac...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "i would offer 4k¥." with entities "[(0, 1, 'per_fir'), (2, 7, 'act_pot'), (8, 13, 'ac...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "if you have new or long-sitting equipment/ invento..." with entities "[(0, 2, 'qattr'), (3, 6, 'per_sec'), (7, 11, 'act_...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "increase the budget from 18k r$ to 23k r$." with entities "[(13, 19, 'cat_bid'), (25, 28, 'pr_val'), (29, 31,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "initial price 25400£." with entities "[(14, 19, 'pr_val'), (19, 20, 'pr_curr')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "installed ltx-credence diamond x." with entities "[(0, 9, 'state_inst'), (10, 32, 'eq_mm')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "minimum us$35k each." with entities "[(0, 7, 'cat_min'), (8, 11, 'pr_curr'), (11, 14, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "more than 149,9k$." with entities "[(0, 9, 'cat_min'), (10, 16, 'pr_val'), (16, 17, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "my clients budget is between £22k-£30k." with entities "[(0, 10, 'per_fir'), (11, 17, 'cat_bid'), (21, 28,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "offer of $1m." with entities "[(9, 10, 'pr_curr'), (10, 12, 'pr_val')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "original price is over 40k€." with entities "[(18, 22, 'cat_min'), (23, 26, 'pr_val'), (26, 27,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "our boss estimates 70k€." with entities "[(0, 8, 'per_fir'), (19, 22, 'pr_val'), (22, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "our bottom price is 20.000€." with entities "[(4, 10, 'cat_min'), (20, 26, 'pr_val'), (26, 27, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "our colleagues wants to sell their seiko / epson n..." with entities "[(0, 14, 'per_fir'), (15, 20, 'act_int'), (21, 28,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "our offer price is us$8,000 each." with entities "[(19, 22, 'pr_curr'), (22, 27, 'pr_val'), (28, 32,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "our team could pay 9k$." with entities "[(0, 8, 'per_fir'), (9, 14, 'act_pot'), (15, 18, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "over 58k$usd." with entities "[(0, 4, 'cat_min'), (5, 8, 'pr_val'), (8, 12, 'pr_...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pictures can be viewed here https//caeonline.com/b..." with entities "[(0, 8, 'aattr'), (9, 12, 'act_pot'), (64, 73, 'eq...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "price is usd$6k ex-works." with entities "[(9, 12, 'pr_curr'), (12, 13, 'pr_curr'), (13, 15,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prices to you us$300,000.00." with entities "[(10, 13, 'per_sec'), (14, 17, 'pr_curr'), (17, 27...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "reduced the price from 67k¥ to 57k¥." with entities "[(23, 26, 'pr_val'), (26, 27, 'pr_curr'), (31, 34,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "selling at kč 1m." with entities "[(0, 7, 'act_sell'), (11, 13, 'pr_curr'), (14, 16,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "spend between $7k-$11k." with entities "[(0, 5, 'act_pay'), (6, 13, 'cat_rang'), (14, 15, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "system for 21k$." with entities "[(0, 6, 'eq_type'), (11, 14, 'pr_val'), (14, 15, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "t5377 x1 @usd 100,000." with entities "[(0, 8, 'eq_mm'), (10, 13, 'pr_curr'), (14, 21, 'p...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "target price about usd$12000." with entities "[(19, 23, 'pr_curr'), (23, 28, 'pr_val')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the asking price of this takatori mws 610sd(2002) ..." with entities "[(4, 16, 'cat_ask'), (25, 43, 'eq_mm'), (44, 48, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the budget $4,000-$6,000 us dollar." with entities "[(0, 10, 'cat_bid'), (11, 12, 'pr_curr'), (12, 17,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the budget would be around 4k$." with entities "[(4, 10, 'cat_bid'), (11, 19, 'act_pot'), (27, 29,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the cost is 13k$." with entities "[(12, 15, 'pr_val'), (15, 16, 'pr_curr')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the owner is asking usd$451k." with entities "[(0, 9, 'per_thr'), (13, 19, 'cat_ask'), (20, 24, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the price for a fully refurbished pma 700 5" is 12..." with entities "[(16, 33, 'cond_ref'), (34, 41, 'eq_mm'), (42, 44,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "the price we are going to sell is us$180k/set." with entities "[(10, 12, 'per_fir'), (13, 25, 'act_pot'), (26, 30...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "these 2 sets of mc-260's turbo pumps are both not ..." with entities "[(6, 7, 'qty_num'), (8, 12, 'eq_type'), (16, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "these are available at 44.000k£ each." with entities "[(6, 19, 'act_have'), (23, 30, 'pr_val'), (30, 31,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "they are going to release both units at 33k¥." with entities "[(0, 4, 'per_thr'), (5, 17, 'act_pot'), (18, 25, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "they are looking at $75k-$85k range for this syste..." with entities "[(0, 4, 'per_thr'), (5, 19, 'act_int'), (20, 21, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "unasix vlr700 g3 for mask dry etcher sigmameltec s..." with entities "[(0, 16, 'eq_mm'), (21, 36, 'eq_type'), (37, 56, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "us$40k for all 3 for package." with entities "[(0, 3, 'pr_curr'), (3, 6, 'pr_val'), (7, 16, 'pr_...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we are available to give 10k€ for the item." with entities "[(0, 2, 'per_fir'), (25, 28, 'pr_val'), (28, 29, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we are looking to get 373k¥ for this unit." with entities "[(0, 2, 'per_fir'), (3, 17, 'act_int'), (22, 26, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we have a 5781 s." with entities "[(0, 2, 'per_fir'), (3, 7, 'act_have'), (10, 16, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we keep looking for 6"~8"amat centura etch 8" p500..." with entities "[(0, 2, 'per_fir'), (8, 19, 'act_int'), (20, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we may have an installed ltx-credence diamond x." with entities "[(0, 2, 'per_fir'), (3, 6, 'act_pot'), (7, 11, 'ac...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/tfsservices/miniconda3/envs/nlp_test/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "we may offer 5. 000£." with entities "[(0, 2, 'per_fir'), (3, 6, 'act_pot'), (7, 12, 'ac...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
# tags_ = ['U-pr_curr', 'B-pr_val', 'I-pr_val', 'L-pr_val', 'O', 'O', 'O', 'O', 'O', 'O', 'B-eq_mm', 'I-eq_mm', 'I-eq_mm', 'L-eq_mm', 'O']

# tags_ = [t_.replace("U-", "B-").replace("L-", "I-") for t_ in tags_]
# print(tags_)

# test_text = "we may offer 5. 000£."
# test_text = "$1mil-$1.6mil for a tool."
test_text ="we have a 5781 s."
doc = nlp(test_text)

utterance_ = ' '.join([str(t) for t in doc])

print(utterance_)
# Out:
# $ 1mil-$1.6mil for a tool .

# %%
# test_text = "we may offer 5. 000£."

from transformers import BertTokenizerFast
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')

encoded = tokenizer(test_text)
# print(encoded)

toks = tokenizer.convert_ids_to_tokens(encoded['input_ids'])
print(toks)


# import torchtext
# from torchtext.data import get_tokenizer
# tokenizer = get_tokenizer("basic_english")
# tokens = tokenizer(test_text)
# tokens
# Out:
# ['[CLS]', '$', '1', '##mi', '##l', '-', '$', '1', '.', '6', '##mi', '##l', 'for', 'a', 'tool', '.', '[SEP]']
